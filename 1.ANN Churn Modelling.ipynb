# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.9.1-cp39-cp39-win_amd64.whl (444.0 MB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\gyanendra singh\anaconda3\lib\site-packages (from tensorflow) (3.10.0.2)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Using cached tensorflow_io_gcs_filesystem-0.26.0-cp39-cp39-win_amd64.whl (1.5 MB)
# Collecting tensorboard<2.10,>=2.9
#   Using cached tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\gyanendra singh\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\gyanendra singh\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Collecting flatbuffers<2,>=1.12
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Using cached grpcio-1.47.0-cp39-cp39-win_amd64.whl (3.6 MB)
# Requirement already satisfied: setuptools in c:\users\gyanendra singh\anaconda3\lib\site-packages (from tensorflow) (58.0.4)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\gyanendra singh\anaconda3\lib\site-packages (from tensorflow) (3.2.1)
# Requirement already satisfied: packaging in c:\users\gyanendra singh\anaconda3\lib\site-packages (from tensorflow) (21.0)
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: numpy>=1.20 in c:\users\gyanendra singh\anaconda3\lib\site-packages (from tensorflow) (1.20.3)
# Collecting keras-preprocessing>=1.1.1
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting keras<2.10.0,>=2.9.0rc0
#   Using cached keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-1.1.0-py3-none-any.whl (123 kB)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting tensorflow-estimator<2.10.0,>=2.9.0rc0
#   Using cached tensorflow_estimator-2.9.0-py2.py3-none-any.whl (438 kB)
# Collecting protobuf<3.20,>=3.9.2
#   Using cached protobuf-3.19.4-cp39-cp39-win_amd64.whl (895 kB)
# Collecting libclang>=13.0.0
#   Using cached libclang-14.0.1-py2.py3-none-win_amd64.whl (14.2 MB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-1.1.0.tar.gz (3.9 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\gyanendra singh\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\gyanendra singh\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.0.2)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\gyanendra singh\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.26.0)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.9.0-py2.py3-none-any.whl (167 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.3.7-py3-none-any.whl (97 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.8-py3-none-any.whl (39 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\gyanendra singh\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\gyanendra singh\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (3.6.0)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gyanendra singh\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\gyanendra singh\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\gyanendra singh\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gyanendra singh\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (3.2)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\gyanendra singh\anaconda3\lib\site-packages (from packaging->tensorflow) (3.0.4)
# Building wheels for collected packages: termcolor
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4847 sha256=504224e517d9802aa21fd75d622e2eab253ec94de2503483620e2630bf288176
#   Stored in directory: c:\users\gyanendra singh\appdata\local\pip\cache\wheels\b6\0d\90\0d1bbd99855f99cb2f6c2e5ff96f8023fad8ec367695f7d72d
# Successfully built termcolor
# Installing collected packages: pyasn1, rsa, pyasn1-modules, oauthlib, cachetools, requests-oauthlib, google-auth, tensorboard-plugin-wit, tensorboard-data-server, protobuf, markdown, grpcio, google-auth-oauthlib, absl-py, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard, opt-einsum, libclang, keras-preprocessing, keras, google-pasta, gast, flatbuffers, astunparse, tensorflow
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.0
#     Uninstalling protobuf-3.20.0:
#       Successfully uninstalled protobuf-3.20.0
# Successfully installed absl-py-1.1.0 astunparse-1.6.3 cachetools-5.2.0 flatbuffers-1.12 gast-0.4.0 google-auth-2.9.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.47.0 keras-2.9.0 keras-preprocessing-1.1.2 libclang-14.0.1 markdown-3.3.7 oauthlib-3.2.0 opt-einsum-3.3.0 protobuf-3.19.4 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.1 rsa-4.8 tensorboard-2.9.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.9.1 tensorflow-estimator-2.9.0 tensorflow-io-gcs-filesystem-0.26.0 termcolor-1.1.0

# %%
import tensorflow as tf
import pandas as pd
import numpy as np

# %%
tf.__version__
# Out:
# '2.9.1'

# %%
df=pd.read_csv(r"C:\Users\gyanendra singh\Downloads\Churn_Modelling.csv")

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
data=df.iloc[:,~df.columns.isin(['RowNumber','CustomerId','Surname'])]

data
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
dfle = data
dfle.Gender = le.fit_transform(dfle.Gender)
dfle.Geography=le.fit_transform(dfle.Geography)
# Out:
# C:\Users\gyanendra singh\anaconda3\lib\site-packages\pandas\core\generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
dfle
# Out:
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619          0       0   42       2       0.00              1
# 1             608          2       0   41       1   83807.86              1
# 2             502          0       0   42       8  159660.80              3
# 3             699          0       0   39       1       0.00              2
# 4             850          2       0   43       2  125510.82              1
# ...           ...        ...     ...  ...     ...        ...            ...
# 9995          771          0       1   39       5       0.00              2
# 9996          516          0       1   35      10   57369.61              1
# 9997          709          0       0   36       7       0.00              1
# 9998          772          1       1   42       3   75075.31              2
# 9999          792          0       0   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
X=dfle.drop(['Exited'],axis=1)
y=dfle.Exited

# %%
data.Geography.value_counts()
# Out:
# 0    5014
# 1    2509
# 2    2477
# Name: Geography, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8, 8))
sns.heatmap(data.corr(),annot=True)
plt.show()

# %%
X
# Out:
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619          0       0   42       2       0.00              1
# 1             608          2       0   41       1   83807.86              1
# 2             502          0       0   42       8  159660.80              3
# 3             699          0       0   39       1       0.00              2
# 4             850          2       0   43       2  125510.82              1
# ...           ...        ...     ...  ...     ...        ...            ...
# 9995          771          0       1   39       5       0.00              2
# 9996          516          0       1   35      10   57369.61              1
# 9997          709          0       0   36       7       0.00              1
# 9998          772          1       1   42       3   75075.31              2
# 9999          792          0       0   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 0             1               1        101348.88
# 1             0               1        112542.58
# 2             1               0        113931.57
# 3             0               0         93826.63
# 4             1               1         79084.10
# ...         ...             ...              ...
# 9995          1               0         96270.64
# 9996          1               1        101699.77
# 9997          0               1         42085.58
# 9998          1               0         92888.52
# 9999          1               0         38190.78
#
# [10000 rows x 10 columns]

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
ann = tf.keras.models.Sequential() #initializing ANN

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %%
ann.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))#outputlayer

# %%
ann.compile(optimizer='adam' ,loss= 'binary_crossentropy', metrics=['accuracy']) #compoling the ANN

# %%
#training ANN for training set
ann.fit(X_train,y_train,batch_size=32,epochs=100)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.6073 - accuracy: 0.7206
# Epoch 2/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4895 - accuracy: 0.7960
# Epoch 3/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4559 - accuracy: 0.7977
# Epoch 4/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4400 - accuracy: 0.8034
# Epoch 5/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4296 - accuracy: 0.8129
# Epoch 6/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4201 - accuracy: 0.8199
# Epoch 7/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4105 - accuracy: 0.8259
# Epoch 8/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4008 - accuracy: 0.8338
# Epoch 9/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3913 - accuracy: 0.8381
# Epoch 10/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3840 - accuracy: 0.8420
# Epoch 11/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3775 - accuracy: 0.8436
# Epoch 12/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3729 - accuracy: 0.8462
# Epoch 13/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3692 - accuracy: 0.8462
# Epoch 14/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3664 - accuracy: 0.8496
# Epoch 15/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3642 - accuracy: 0.8493
# Epoch 16/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3627 - accuracy: 0.8509
# Epoch 17/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3614 - accuracy: 0.8515
# Epoch 18/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3597 - accuracy: 0.8528
# Epoch 19/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3592 - accuracy: 0.8525
# Epoch 20/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3585 - accuracy: 0.8544
# Epoch 21/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3576 - accuracy: 0.8536
# Epoch 22/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3570 - accuracy: 0.8533
# Epoch 23/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3563 - accuracy: 0.8541
# Epoch 24/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3557 - accuracy: 0.8558
# Epoch 25/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3555 - accuracy: 0.8543
# Epoch 26/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3552 - accuracy: 0.8558
# Epoch 27/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3542 - accuracy: 0.8554
# Epoch 28/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3540 - accuracy: 0.8546
# Epoch 29/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3539 - accuracy: 0.8564
# Epoch 30/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3534 - accuracy: 0.8555
# Epoch 31/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3533 - accuracy: 0.8568
# Epoch 32/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3524 - accuracy: 0.8554
# Epoch 33/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3525 - accuracy: 0.8550
# Epoch 34/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3514 - accuracy: 0.8558
# Epoch 35/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3514 - accuracy: 0.8569
# Epoch 36/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3511 - accuracy: 0.8566
# Epoch 37/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3504 - accuracy: 0.8553
# Epoch 38/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3501 - accuracy: 0.8570
# Epoch 39/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3497 - accuracy: 0.8579
# Epoch 40/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3496 - accuracy: 0.8587
# Epoch 41/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3489 - accuracy: 0.8570
# Epoch 42/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3488 - accuracy: 0.8561
# Epoch 43/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3484 - accuracy: 0.8586
# Epoch 44/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3484 - accuracy: 0.8590
# Epoch 45/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3478 - accuracy: 0.8583
# Epoch 46/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3476 - accuracy: 0.8577
# Epoch 47/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3473 - accuracy: 0.8574
# Epoch 48/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3470 - accuracy: 0.8566
# Epoch 49/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3470 - accuracy: 0.8574
# Epoch 50/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3466 - accuracy: 0.8571
# Epoch 51/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3462 - accuracy: 0.8586
# Epoch 52/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3463 - accuracy: 0.8580
# Epoch 53/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3459 - accuracy: 0.8579
# Epoch 54/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3455 - accuracy: 0.8572
# Epoch 55/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3454 - accuracy: 0.8569
# Epoch 56/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3451 - accuracy: 0.8576
# Epoch 57/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3446 - accuracy: 0.8571
# Epoch 58/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3447 - accuracy: 0.8579
# Epoch 59/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3442 - accuracy: 0.8577
# Epoch 60/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3443 - accuracy: 0.8581
# Epoch 61/100
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3438 - accuracy: 0.8574
# Epoch 62/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3432 - accuracy: 0.8576
# Epoch 63/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3432 - accuracy: 0.8580
# Epoch 64/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3429 - accuracy: 0.8572
# Epoch 65/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3427 - accuracy: 0.8583
# Epoch 66/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3420 - accuracy: 0.8599
# Epoch 67/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3420 - accuracy: 0.8587
# Epoch 68/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3417 - accuracy: 0.8586
# Epoch 69/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3411 - accuracy: 0.8594
# Epoch 70/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3409 - accuracy: 0.8597
# Epoch 71/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3407 - accuracy: 0.8590
# Epoch 72/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3406 - accuracy: 0.8599
# Epoch 73/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3401 - accuracy: 0.8604
# Epoch 74/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3403 - accuracy: 0.8602
# Epoch 75/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3395 - accuracy: 0.8604
# Epoch 76/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3399 - accuracy: 0.8602
# Epoch 77/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3392 - accuracy: 0.8615
# Epoch 78/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3393 - accuracy: 0.8611
# Epoch 79/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3390 - accuracy: 0.8614
# Epoch 80/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3384 - accuracy: 0.8608
# Epoch 81/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3390 - accuracy: 0.8620
# Epoch 82/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3387 - accuracy: 0.8610
# Epoch 83/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3384 - accuracy: 0.8616
# Epoch 84/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3384 - accuracy: 0.8601
# Epoch 85/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3385 - accuracy: 0.8612
# Epoch 86/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3379 - accuracy: 0.8619
# Epoch 87/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3382 - accuracy: 0.8608
# Epoch 88/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3379 - accuracy: 0.8615
# Epoch 89/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3378 - accuracy: 0.8630
# Epoch 90/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3377 - accuracy: 0.8620
# Epoch 91/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3378 - accuracy: 0.8615
# Epoch 92/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3375 - accuracy: 0.8619
# Epoch 93/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3375 - accuracy: 0.8624
# Epoch 94/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3373 - accuracy: 0.8622
# Epoch 95/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3371 - accuracy: 0.8622
# Epoch 96/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3372 - accuracy: 0.8620
# Epoch 97/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3370 - accuracy: 0.8621
# Epoch 98/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3370 - accuracy: 0.8625
# Epoch 99/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3371 - accuracy: 0.8610
# Epoch 100/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3365 - accuracy: 0.8641

# %%
print(ann.predict(sc.transform([[600,0,1,40,3,60000,2,1,1,50000]])) > 0.5)
# Out:
# 1/1 [==============================] - 0s 47ms/step
# [[False]]
# C:\Users\gyanendra singh\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
ann.predict(X_test)
# Out:
# 63/63 [==============================] - 0s 515us/step
# array([[0.21875226],
#        [0.24284598],
#        [0.19603908],
#        ...,
#        [0.07810421],
#        [0.16548657],
#        [0.11975451]], dtype=float32)

# %%
X_test
# Out:
# array([[-0.55204276,  0.3131264 , -1.09168714, ...,  0.64259497,
#          0.9687384 ,  1.61085707],
#        [-1.31490297, -0.89294542, -1.09168714, ...,  0.64259497,
#         -1.03227043,  0.49587037],
#        [ 0.57162971,  1.51919821, -1.09168714, ...,  0.64259497,
#          0.9687384 , -0.42478674],
#        ...,
#        [-0.74791227,  1.51919821,  0.91601335, ...,  0.64259497,
#         -1.03227043,  0.71888467],
#        [-0.00566991,  0.3131264 ,  0.91601335, ...,  0.64259497,
#          0.9687384 , -1.54507805],
#        [-0.79945688,  0.3131264 ,  0.91601335, ...,  0.64259497,
#         -1.03227043,  1.61255917]])
